# %% [markdown]
# # Atividade de Pandas -
#
# #### Conteúdo:
# - Operações básicas

# %% [markdown]
# **Importe o pandas como pd.**

# %% [markdown]
# **Leia o dataset chamado ``air_quality_no2.csv``**.

# %% [markdown]
# **Apresente o Cabeçalho do Dataset**

# %%
# Out:
#               datetime  station_antwerp  station_paris  station_london
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN

# %% [markdown]
# **Use o método .info () para descobrir quantas entradas existem.**

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   datetime         1035 non-null   object
#  1   station_antwerp  95 non-null     float64
#  2   station_paris    1004 non-null   float64
#  3   station_london   969 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 32.5+ KB

# %% [markdown]
# - **Crie uma nova coluna ``london_mg_per_cubic`` para concentração de NO2 in mg/m³**
#
# Assuma que a temperatura de 25 graus Celsius e pressão de 1013 hPa. Use o o fator de conversão é 1,882)

# %%
# Out:
#               datetime  station_antwerp  station_paris  station_london  \
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
#
#    london_mg_per_cubic
# 0               43.286
# 1               35.758
# 2               35.758
# 3               30.112
# 4                  NaN

# %% [markdown]
# - **Crie uma nova coluna ``ratio_paris_antwerp`` fazendo a relação entre ``station_paris`` e ``station_antwerp``**

# %%
# Out:
#               datetime  station_antwerp  station_paris  station_london  \
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
#
#    london_mg_per_cubic  ratio_paris_antwerp
# 0               43.286                  NaN
# 1               35.758             0.495050
# 2               35.758             0.615556
# 3               30.112                  NaN
# 4                  NaN                  NaN

# %% [markdown]
# **Renomeie as colunas**
# - station_antwerp para BETR801
# - station_paris para FR04014
# - station_london para London Westminster

# %%
# Out:
#                  datetime  BETR801  FR04014  London Westminster  \
# 0     2019-05-07 02:00:00      NaN      NaN                23.0
# 1     2019-05-07 03:00:00     50.5     25.0                19.0
# 2     2019-05-07 04:00:00     45.0     27.7                19.0
# 3     2019-05-07 05:00:00      NaN     50.4                16.0
# 4     2019-05-07 06:00:00      NaN     61.9                 NaN
# ...                   ...      ...      ...                 ...
# 1030  2019-06-20 22:00:00      NaN     21.4                 NaN
# 1031  2019-06-20 23:00:00      NaN     24.9                 NaN
# 1032  2019-06-21 00:00:00      NaN     26.5                 NaN
# 1033  2019-06-21 01:00:00      NaN     21.8                 NaN
# 1034  2019-06-21 02:00:00      NaN     20.0                 NaN
#
#       london_mg_per_cubic  ratio_paris_antwerp
# 0                  43.286                  NaN
# 1                  35.758             0.495050
# 2                  35.758             0.615556
# ...

# %% [markdown]
# - **Mude o nome de todas as colunas usando lower case**

# %%
# Out:
#                  datetime  station_antwerp  station_paris  station_london  \
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# 3     2019-05-07 05:00:00              NaN           50.4            16.0
# 4     2019-05-07 06:00:00              NaN           61.9             NaN
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
#       london_mg_per_cubic  ratio_paris_antwerp
# ...

# %% [markdown]
# - **Ordene os dados pelo london_mg_per_cubic do maior para o menor**

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   datetime             1035 non-null   object
#  1   station_antwerp      95 non-null     float64
#  2   station_paris        1004 non-null   float64
#  3   station_london       969 non-null    float64
#  4   london_mg_per_cubic  969 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 40.6+ KB

# %%
# Out:
#                  datetime  station_antwerp  station_paris  station_london  \
# 62    2019-05-09 16:00:00              NaN           24.6            97.0
# 63    2019-05-09 17:00:00              NaN           23.9            67.0
# 68    2019-05-09 22:00:00              NaN           29.2            65.0
# 66    2019-05-09 20:00:00              NaN           24.4            62.0
# 64    2019-05-09 18:00:00              NaN           27.0            60.0
# ...                   ...              ...            ...             ...
# 1030  2019-06-20 22:00:00              NaN           21.4             NaN
# 1031  2019-06-20 23:00:00              NaN           24.9             NaN
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
#       london_mg_per_cubic
# 62                182.554
# ...

# %% [markdown]
# - **Set o index para o atributo datetime**

# %%
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# ...
