# %% [markdown]
# # Atividade de Pandas -
# #### Conteúdos:
# - Seleção de Dados
#
#
# use o dataset: **COVID19 cases Toronto.csv**

# %%
import pandas as pd

# %%
filename = '../data/COVID19 cases Toronto.csv'
df = pd.read_csv(filename)

# %% [markdown]
# **1. Apresente uma função que irá retornar 10% de registros aleatórios do dataset COVID19 cases Toronto.csv**

# %%
df.sample(frac=0.1)
# Out:
#          _id  Outbreak Associated       Age Group  \
# 8642   52936  Outbreak Associated           60-69
# 4785   49079             Sporadic           20-29
# 1778   46072             Sporadic           40-49
# 11354  55648  Outbreak Associated             90+
# 6175   50469             Sporadic           50-59
# ...      ...                  ...             ...
# 14810  59104  Outbreak Associated             90+
# 14708  59002             Sporadic           20-29
# 9391   53685  Outbreak Associated           30-39
# 13229  57523  Outbreak Associated  19 and younger
# 14363  58657  Outbreak Associated           40-49
#
#                       Neighbourhood Name  FSA        Source of Infection  \
# 8642                     Oakwood Village  M6C  N/A - Outbreak associated
# 4785             York University Heights  M3J              Close contact
# 1778                            Oakridge  M1L                    Pending
# 11354         Islington-City Centre West  M9B  N/A - Outbreak associated
# 6175                   O'Connor-Parkview  M4B              Close contact
# ...                                  ...  ...                        ...
# 14810                                NaN  NaN  N/A - Outbreak associated
# 14708                                NaN  NaN                  Community
# 9391                      South Parkdale  M6K  N/A - Outbreak associated
# 13229  Mount Olive-Silverstone-Jamestown  M9V  N/A - Outbreak associated
# 14363                                NaN  NaN  N/A - Outbreak associated
#
#       Classification Episode Date Reported Date Client Gender   Outcome  \
# 8642       CONFIRMED   2020-05-20    2020-05-20          MALE  RESOLVED
# 4785       CONFIRMED   2020-04-23    2020-05-05        FEMALE  RESOLVED
# 1778        PROBABLE   2020-04-14    2020-04-14          MALE  RESOLVED
# 11354      CONFIRMED   2020-03-24    2020-04-14        FEMALE  RESOLVED
# 6175        PROBABLE   2020-06-18    2020-06-25        FEMALE  RESOLVED
# ...              ...          ...           ...           ...       ...
# 14810      CONFIRMED   2020-04-27    2020-04-29        FEMALE  RESOLVED
# 14708      CONFIRMED   2020-04-18    2020-04-20          MALE  RESOLVED
# 9391       CONFIRMED   2020-05-22    2020-05-24        FEMALE  RESOLVED
# 13229      CONFIRMED   2020-06-24    2020-06-27          MALE  RESOLVED
# 14363      CONFIRMED   2020-04-27    2020-05-03        FEMALE  RESOLVED
#
#       Currently Hospitalized Currently in ICU Currently Intubated  \
# 8642                      No               No                  No
# 4785                      No               No                  No
# 1778                      No               No                  No
# 11354                     No               No                  No
# 6175                      No               No                  No
# ...                      ...              ...                 ...
# 14810                     No               No                  No
# 14708                     No               No                  No
# 9391                      No               No                  No
# 13229                     No               No                  No
# 14363                     No               No                  No
#
#       Ever Hospitalized Ever in ICU Ever Intubated
# 8642                 No          No             No
# 4785                 No          No             No
# 1778                 No          No             No
# 11354                No          No             No
# 6175                 No          No             No
# ...                 ...         ...            ...
# 14810                No          No             No
# 14708                No          No             No
# 9391                 No          No             No
# 13229                No          No             No
# 14363                No          No             No
#
# [1491 rows x 17 columns]

# %% [markdown]
# **2. Apresente uma função que irá retornar os dados entre o índice 100 e 120 das colunas Classification e Age Group**

# %%
df.loc[100:120, ['Classification', 'Age Group']]
# Out:
#     Classification       Age Group
# 100      CONFIRMED           60-69
# 101      CONFIRMED           50-59
# 102      CONFIRMED           60-69
# 103      CONFIRMED           60-69
# 104      CONFIRMED           40-49
# 105      CONFIRMED           40-49
# 106      CONFIRMED           70-79
# 107      CONFIRMED           50-59
# 108      CONFIRMED           20-29
# 109      CONFIRMED           60-69
# 110      CONFIRMED           60-69
# 111      CONFIRMED           60-69
# 112      CONFIRMED           50-59
# 113      CONFIRMED           30-39
# 114      CONFIRMED           30-39
# 115       PROBABLE           60-69
# 116      CONFIRMED           30-39
# 117       PROBABLE  19 and younger
# 118       PROBABLE  19 and younger
# 119       PROBABLE           50-59
# 120      CONFIRMED           30-39

# %% [markdown]
# **3. Apresente uma função que irá retornar os dados que estão entre a posições 50 e 70 das colunas últimas seis colunas do dataset**

# %%
df.iloc[50:70, -6:]
# Out:
#    Currently Hospitalized Currently in ICU Currently Intubated  \
# 50                     No               No                  No
# 51                     No               No                  No
# 52                     No               No                  No
# 53                     No               No                  No
# 54                     No               No                  No
# 55                     No               No                  No
# 56                     No               No                  No
# 57                     No               No                  No
# 58                     No               No                  No
# 59                     No               No                  No
# 60                     No               No                  No
# 61                     No               No                  No
# 62                     No               No                  No
# 63                     No               No                  No
# 64                     No               No                  No
# 65                     No               No                  No
# 66                     No               No                  No
# 67                     No               No                  No
# 68                     No               No                  No
# 69                     No               No                  No
#
#    Ever Hospitalized Ever in ICU Ever Intubated
# 50                No          No             No
# 51                No          No             No
# 52                No          No             No
# 53                No          No             No
# 54                No          No             No
# 55               Yes          No             No
# 56                No          No             No
# 57                No          No             No
# 58                No          No             No
# 59               Yes          No             No
# 60                No          No             No
# 61                No          No             No
# 62                No          No             No
# 63                No          No             No
# 64                No          No             No
# 65                No          No             No
# 66                No          No             No
# 67                No          No             No
# 68                No          No             No
# 69                No          No             No

# %% [markdown]
# **4. Apresente um código pandas que retornará os registros que tem idade entre 50 e 59 anos que tiveram casos confirmados**

# %%
df[(df['Age Group'] == '50-59') & (df['Classification']=='CONFIRMED')]
# Out:
#          _id  Outbreak Associated Age Group Neighbourhood Name  FSA  \
# 0      44294             Sporadic     50-59            Malvern  M1B
# 3      44297  Outbreak Associated     50-59              Rouge  M1B
# 16     44310             Sporadic     50-59            Malvern  M1B
# 21     44315             Sporadic     50-59            Malvern  M1B
# 22     44316             Sporadic     50-59            Malvern  M1B
# ...      ...                  ...       ...                ...  ...
# 14892  59186  Outbreak Associated     50-59                NaN  NaN
# 14901  59195  Outbreak Associated     50-59                NaN  NaN
# 14905  59199  Outbreak Associated     50-59                NaN  NaN
# 14906  59200  Outbreak Associated     50-59                NaN  NaN
# 14910  59204  Outbreak Associated     50-59                NaN  NaN
#
#              Source of Infection Classification Episode Date Reported Date  \
# 0                  Institutional      CONFIRMED   2020-03-25    2020-03-27
# 3      N/A - Outbreak associated      CONFIRMED   2020-05-02    2020-05-04
# 16                 Institutional      CONFIRMED   2020-04-13    2020-04-15
# 21                 Close contact      CONFIRMED   2020-04-25    2020-05-01
# 22                 Close contact      CONFIRMED   2020-05-01    2020-05-07
# ...                          ...            ...          ...           ...
# 14892  N/A - Outbreak associated      CONFIRMED   2020-05-23    2020-05-25
# 14901  N/A - Outbreak associated      CONFIRMED   2020-05-24    2020-05-25
# 14905  N/A - Outbreak associated      CONFIRMED   2020-06-02    2020-06-03
# 14906  N/A - Outbreak associated      CONFIRMED   2020-06-11    2020-06-15
# 14910  N/A - Outbreak associated      CONFIRMED   2020-06-22    2020-06-23
#
#       Client Gender   Outcome Currently Hospitalized Currently in ICU  \
# 0              MALE  RESOLVED                     No               No
# 3            FEMALE  RESOLVED                     No               No
# 16           FEMALE  RESOLVED                     No               No
# 21           FEMALE  RESOLVED                     No               No
# 22             MALE  RESOLVED                     No               No
# ...             ...       ...                    ...              ...
# 14892          MALE  RESOLVED                     No               No
# 14901          MALE  RESOLVED                     No               No
# 14905        FEMALE  RESOLVED                     No               No
# 14906        FEMALE  RESOLVED                     No               No
# 14910        FEMALE  RESOLVED                     No               No
#
#       Currently Intubated Ever Hospitalized Ever in ICU Ever Intubated
# 0                      No                No          No             No
# 3                      No                No          No             No
# 16                     No                No          No             No
# 21                     No                No          No             No
# 22                     No               Yes          No             No
# ...                   ...               ...         ...            ...
# 14892                  No                No          No             No
# 14901                  No                No          No             No
# 14905                  No                No          No             No
# 14906                  No                No          No             No
# 14910                  No               Yes          No             No
#
# [2221 rows x 17 columns]

# %% [markdown]
# **5. Apresente um código pandas que retornará os registros dos seguintes bairros ['Malvern', 'Rouge', 'Thorncliffe Park', 'Bendale']**

# %%
df[df['Neighbourhood Name'].isin(['Malvern', 'Rouge', 'Thorncliffe Park', 'Bendale'])]
# Out:
#         _id  Outbreak Associated Age Group Neighbourhood Name  FSA  \
# 0     44294             Sporadic     50-59            Malvern  M1B
# 1     44295             Sporadic     20-29            Malvern  M1B
# 2     44296             Sporadic     60-69            Malvern  M1B
# 3     44297  Outbreak Associated     50-59              Rouge  M1B
# 4     44298             Sporadic     30-39              Rouge  M1B
# ...     ...                  ...       ...                ...  ...
# 6501  50795             Sporadic     20-29   Thorncliffe Park  M4H
# 6502  50796             Sporadic     60-69   Thorncliffe Park  M4H
# 6503  50797  Outbreak Associated     50-59   Thorncliffe Park  M4H
# 6504  50798             Sporadic     30-39   Thorncliffe Park  M4H
# 6505  50799             Sporadic     50-59   Thorncliffe Park  M4H
#
#             Source of Infection Classification Episode Date Reported Date  \
# 0                 Institutional      CONFIRMED   2020-03-25    2020-03-27
# 1                     Community      CONFIRMED   2020-03-20    2020-03-28
# 2                        Travel      CONFIRMED   2020-03-04    2020-03-08
# 3     N/A - Outbreak associated      CONFIRMED   2020-05-02    2020-05-04
# 4                 Close contact      CONFIRMED   2020-05-31    2020-06-06
# ...                         ...            ...          ...           ...
# 6501              Close contact       PROBABLE   2020-06-11    2020-06-14
# 6502              Close contact      CONFIRMED   2020-06-05    2020-06-13
# 6503  N/A - Outbreak associated      CONFIRMED   2020-04-05    2020-04-07
# 6504                  Community      CONFIRMED   2020-04-12    2020-04-17
# 6505                 Healthcare      CONFIRMED   2020-04-04    2020-04-07
#
#      Client Gender   Outcome Currently Hospitalized Currently in ICU  \
# 0             MALE  RESOLVED                     No               No
# 1             MALE  RESOLVED                     No               No
# 2           FEMALE  RESOLVED                     No               No
# 3           FEMALE  RESOLVED                     No               No
# 4           FEMALE  RESOLVED                     No               No
# ...            ...       ...                    ...              ...
# 6501          MALE  RESOLVED                     No               No
# 6502          MALE  RESOLVED                     No               No
# 6503        FEMALE  RESOLVED                     No               No
# 6504          MALE  RESOLVED                     No               No
# 6505          MALE  RESOLVED                     No               No
#
#      Currently Intubated Ever Hospitalized Ever in ICU Ever Intubated
# 0                     No                No          No             No
# 1                     No               Yes          No             No
# 2                     No               Yes         Yes            Yes
# 3                     No                No          No             No
# 4                     No                No          No             No
# ...                  ...               ...         ...            ...
# 6501                  No                No          No             No
# 6502                  No               Yes          No             No
# 6503                  No                No          No             No
# 6504                  No                No          No             No
# 6505                  No               Yes          No             No
#
# [774 rows x 17 columns]
