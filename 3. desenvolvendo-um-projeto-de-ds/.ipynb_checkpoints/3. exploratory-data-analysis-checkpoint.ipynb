# %%
import pandas as pd

# %% [markdown]
# ## 1. Leitura dos dados de FILMES

# %%
filename = '../data/netflix_filmes_clear.csv'
df = pd.read_csv(filename, parse_dates=['date_added'])
df.head()
# Out:
#     show_id                                    title      director  \
# 0  81145628  Norm of the North: King Sized Adventure  Richard Finn
# 1  81145628  Norm of the North: King Sized Adventure  Richard Finn
# 2  81145628  Norm of the North: King Sized Adventure  Richard Finn
# 3  81145628  Norm of the North: King Sized Adventure  Richard Finn
# 4  81145628  Norm of the North: King Sized Adventure  Richard Finn
#
#             cast        country date_added  release_year  \
# 0  Alan Marriott  United States 2019-09-09          2019
# 1  Alan Marriott  United States 2019-09-09          2019
# 2  Alan Marriott          India 2019-09-09          2019
# 3  Alan Marriott          India 2019-09-09          2019
# 4  Alan Marriott    South Korea 2019-09-09          2019
#
#                   listed_in  \
# 0  Children & Family Movies
# 1                  Comedies
# 2  Children & Family Movies
# 3                  Comedies
# 4  Children & Family Movies
#
# ...

# %% [markdown]
# ## 2. Processamento

# %% [markdown]
# #### verificação dos formatos dos dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95043 entries, 0 to 95042
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   show_id         95043 non-null  int64
#  1   title           95043 non-null  object
#  2   director        95043 non-null  object
#  3   cast            95043 non-null  object
#  4   country         95016 non-null  object
#  5   date_added      95043 non-null  datetime64[ns]
#  6   release_year    95043 non-null  int64
#  7   listed_in       95043 non-null  object
#  8   description     95043 non-null  object
#  9   duration_movie  95043 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(6)
# memory usage: 7.3+ MB

# %% [markdown]
# #### verificão dos dados nulos

# %%
df.isna().sum()
# Out:
# show_id            0
# title              0
# director           0
# cast               0
# country           27
# date_added         0
# release_year       0
# listed_in          0
# description        0
# duration_movie     0
# dtype: int64

# %% [markdown]
# #### limpeza de dados

# %%
df[df['country'].isna()]
# Out:
#         show_id          title         director                   cast  \
# 13090  81168347  Hotel Pacific  Janusz Majewski          Marek Kondrat
# 13091  81168347  Hotel Pacific  Janusz Majewski          Marek Kondrat
# 13092  81168347  Hotel Pacific  Janusz Majewski          Marek Kondrat
# 13096  81168347  Hotel Pacific  Janusz Majewski         Roman Wilhelmi
# 13097  81168347  Hotel Pacific  Janusz Majewski         Roman Wilhelmi
# 13098  81168347  Hotel Pacific  Janusz Majewski         Roman Wilhelmi
# 13102  81168347  Hotel Pacific  Janusz Majewski          Roman Skamene
# 13103  81168347  Hotel Pacific  Janusz Majewski          Roman Skamene
# 13104  81168347  Hotel Pacific  Janusz Majewski          Roman Skamene
# 13108  81168347  Hotel Pacific  Janusz Majewski          Čestmír Řanda
# 13109  81168347  Hotel Pacific  Janusz Majewski          Čestmír Řanda
# 13110  81168347  Hotel Pacific  Janusz Majewski          Čestmír Řanda
# ...

# %%
shape_before = df.shape[0]
df.dropna(inplace=True)
print(f'{shape_before-df.shape[0]} linhas foram deletadas')
# Out:
# 27 linhas foram deletadas

# %%
#verificão dos nulos
df.isna().sum()
# Out:
# show_id           0
# title             0
# director          0
# cast              0
# country           0
# date_added        0
# release_year      0
# listed_in         0
# description       0
# duration_movie    0
# dtype: int64

# %% [markdown]
# #### verificão dos dados duplicados

# %%
df[df.duplicated()]
# Out:
#         show_id                title        director                  cast  \
# 12551  81168338  300 Miles to Heaven  Maciej Dejczer  Adrianna Biedrzyńska
# 12552  81168338  300 Miles to Heaven  Maciej Dejczer  Adrianna Biedrzyńska
# 12553  81168338  300 Miles to Heaven  Maciej Dejczer  Adrianna Biedrzyńska
# 12554  81168338  300 Miles to Heaven  Maciej Dejczer  Adrianna Biedrzyńska
# 12555  81168338  300 Miles to Heaven  Maciej Dejczer  Adrianna Biedrzyńska
# 12556  81168338  300 Miles to Heaven  Maciej Dejczer  Adrianna Biedrzyńska
# 43736  81018067      Blood Will Tell    Miguel Cohan        Oscar Martínez
# 43737  81018067      Blood Will Tell    Miguel Cohan        Oscar Martínez
# 43738  81018067      Blood Will Tell    Miguel Cohan        Oscar Martínez
# 43739  81018067      Blood Will Tell    Miguel Cohan        Oscar Martínez
# 43740  81018067      Blood Will Tell    Miguel Cohan        Oscar Martínez
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'listed_in', 'description', 'duration_movie'],
#       dtype='object')

# %%
df['listed_in']
# Out:
# 0        Children & Family Movies
# 1                        Comedies
# 2        Children & Family Movies
# 3                        Comedies
# 4        Children & Family Movies
#                    ...
# 95038                      Dramas
# 95039          Independent Movies
# 95040               Documentaries
# 95041               Sports Movies
# 95042               Documentaries
# Name: listed_in, Length: 95016, dtype: object

# %%
df[df.duplicated()]['show_id'].unique()
# Out:
# array([81168338, 81018067])

# %%
shape_before = df.shape[0]
df.drop_duplicates(inplace=True)
print(f'{shape_before-df.shape[0]} linhas foram deletadas')
# Out:
# 0 linhas foram deletadas
